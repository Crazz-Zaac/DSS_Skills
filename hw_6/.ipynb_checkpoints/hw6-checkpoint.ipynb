# %%
import h5py

# %%
import flammkuchen as fl
import numpy as np
import matplotlib.pyplot as plt

# %%
def calculate_iou(rect1, rect2):
    x1, y1, w1, h1 = rect1
    x2, y2, w2, h2 = rect2

    # Calculating coordinates of intersection rectangle
    x_left = max(x1, x2)
    y_top = max(y1, y2)
    x_right = min(x1 + w1, x2 + w2)
    y_bottom = min(y1 + h1, y2 + h2)

    if x_right < x_left or y_bottom < y_top:
        return 0.0  # No intersection

    # area of intersection rectangle
    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    # area of both rectangles
    area1 = w1 * h1
    area2 = w2 * h2

    # union area
    union_area = area1 + area2 - intersection_area

    # Calculating IoU
    iou = intersection_area / union_area
    return iou

# %%
data = fl.load('rectangles.dsss')
data.keys()
# Out:
# dict_keys(['ground_truth', 'predicted'])

# %%
# Calculate IoU for each pair of rectangles
iou_scores = []
ground_truth_rectangles = data['ground_truth']
predicted_rectangles = data['predicted']

for i in range(len(ground_truth_rectangles)):
    iou = calculate_iou(ground_truth_rectangles[i], predicted_rectangles[i])
    iou_scores.append(iou)

# Plotting histogram of IoU scores
plt.hist(iou_scores, bins=20, edgecolor='black')
plt.xlabel('IoU Score')
plt.ylabel('Frequency')
plt.title('Distribution of IoU Scores')
plt.show()

# %%
# !pip install albumentations
# Out:
# Collecting albumentations
#   Obtaining dependency information for albumentations from https://files.pythonhosted.org/packages/9b/f6/c486cedb4f75147232f32ec4c97026714cfef7c7e247a1f0427bc5489f66/albumentations-1.3.1-py3-none-any.whl.metadata
#   Downloading albumentations-1.3.1-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy>=1.11.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from albumentations) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from albumentations) (1.11.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from albumentations) (0.20.0)
# Requirement already satisfied: PyYAML in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from albumentations) (6.0)
# Collecting qudida>=0.0.4 (from albumentations)
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1 (from albumentations)
#   Obtaining dependency information for opencv-python-headless>=4.1.1 from https://files.pythonhosted.org/packages/9d/d7/e2aaf344254292d2046f9984b54212e4e7d69a57d30ae15e7294840710f6/opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from qudida>=0.0.4->albumentations) (1.3.0)
# Requirement already satisfied: typing-extensions in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from qudida>=0.0.4->albumentations) (4.7.1)
# Requirement already satisfied: networkx>=2.8 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-image>=0.16.1->albumentations) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/blackphoenix/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (2.2.0)
# Downloading albumentations-1.3.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 1.3 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 4.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: opencv-python-headless, qudida, albumentations
# Successfully installed albumentations-1.3.1 opencv-python-headless-4.8.1.78 qudida-0.0.4

# %%
import cv2
import numpy as np
import json
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import albumentations as albm

# %%
np.random.seed(23272000)

# %%
num = np.random.randint(100)
img = cv2.imread('Mini_BAGLS_dataset/'+str(num)+'.png')
mask = cv2.imread('Mini_BAGLS_dataset/'+str(num)+'_seg.png')

# %%
def visualize(image, mask, original_image=None, original_mask=None, trans_text):
    fontsize = 10
    
    if original_image is None and original_mask is None:
        f, ax = plt.subplots(1, 2, figsize=(8, 8))

        ax[0].imshow(image)
        ax[1].imshow(mask)
    else:
        f, ax = plt.subplots(2, 2, figsize=(8, 8))

        ax[0, 0].imshow(original_image)
        ax[0, 0].set_title('Original image', fontsize=fontsize)
        
        ax[0, 1].imshow(original_mask)
        ax[0, 1].set_title('Original mask', fontsize=fontsize)
        
        ax[1, 0].imshow(image)
        ax[1, 0].set_title(trans_text +' image', fontsize=fontsize)
        
        ax[1, 1].imshow(mask)
        ax[1, 1].set_title(trans_text+ ' mask', fontsize=fontsize)

# %%
visualize(img, mask)

# %%
aug = albm.VerticalFlip(p=1)

augmented = aug(image=img, mask=mask)

image_h_flipped = augmented['image']
mask_h_flipped = augmented['mask']

visualize(image_h_flipped, mask_h_flipped, original_image=img, original_mask=mask)
